# %%
import pandas as pd
import numpy as np

# %%
def create_dict():
    dict_1 = dict()
    for i in range(20):
        if(i != 0):
            dict_1["On a scale of 1-10 how warm is the song? (10 corresponds to very warm)."+str(i)] = "q"+str(i)+"_warm"
            dict_1["On a scale of 1-10 how acoustic is the song? (10 corresponds to very acoustic)."+str(i)] = "q"+str(i)+"_acoustic"
            dict_1["On a scale of 1-10 how colourful is the song? (10 corresponds to very colourful)."+str(i)] = "q"+str(i)+"_coloutful"
            dict_1["On a scale of 1-10 how full is the song? (10 corresponds to very full)."+str(i)] = "q"+str(i)+"_full"
            dict_1["On a scale of 1-10 how Energetic is the song? (10 corresponds to very Energetic)."+str(i)] = "q"+str(i)+"_full"
        else:
            dict_1["On a scale of 1-10 how warm is the song? (10 corresponds to very warm)"] = "q"+str(i)+"_warm"
            dict_1["On a scale of 1-10 how acoustic is the song? (10 corresponds to very acoustic)"] = "q"+str(i)+"_acoustic"
            dict_1["On a scale of 1-10 how colourful is the song? (10 corresponds to very colourful)"] = "q"+str(i)+"_colourful"
            dict_1["On a scale of 1-10 how full is the song? (10 corresponds to very full)"] = "q"+str(i)+"_full"
            dict_1["On a scale of 1-10 how Energetic is the song? (10 corresponds to very Energetic)"] = "q"+str(i)+"_energy"
    return dict_1

# %%
df = pd.read_csv('./data.csv')
df = df.drop(['Timestamp'], axis = 1)
df = df.rename(columns={"Enter the amount of experience you have in music (Instruments or Vocals)":"experience", "Please enter your age in years":"age", "Please select your gender":"gender"})
df = df.rename(columns=create_dict())
df.head()
# Out:
#              experience  age  gender  q0_warm  q0_acoustic  q0_colourful
# 0      3 years - 1 Year   21  Female        7            8             7  \
# 1         No Experience   22  Female        3            4             7
# 2      3 years - 1 Year   20  Female        7            9             9
# 3  Greater than 3 years   29    Male       10            9            10
# 4      Less than 1 Year   20    Male        6            7             8
#
#    q0_full  q0_energy  q1_warm  q1_acoustic  ...  q18_warm  q18_acoustic
# 0        7          7        7            7  ...         9             8  \
# 1        4          3        4            3  ...         8             7
# 2        9         10        5            5  ...         8             9
# 3       10          9       10            6  ...         6            10
# 4        6          8        5            4  ...         6             6
#
#    q18_coloutful  q18_full  q18_full  q19_warm  q19_acoustic  q19_coloutful
# 0              9         9         9         8             8              8  \
# 1              6         7         4         7             4              7
# 2              9         9         9         8             5              8
# 3              8         4         4         1             5             10
# 4              5         5         5         6             5              5
#
#    q19_full  q19_full
# 0         8         8
# 1         7         4
# 2         6         8
# 3        10        10
# 4         5         6
#
# [5 rows x 103 columns]

# %%
gender = df['gender']
age = df['age']
df = df.drop(['gender', 'age'], axis = 1)
df.head()
# Out:
#              experience  q0_warm  q0_acoustic  q0_colourful  q0_full
# 0      3 years - 1 Year        7            8             7        7  \
# 1         No Experience        3            4             7        4
# 2      3 years - 1 Year        7            9             9        9
# 3  Greater than 3 years       10            9            10       10
# 4      Less than 1 Year        6            7             8        6
#
#    q0_energy  q1_warm  q1_acoustic  q1_coloutful  q1_full  ...  q18_warm
# 0          7        7            7             8        8  ...         9  \
# 1          3        4            3             7        5  ...         8
# 2         10        5            5             5        5  ...         8
# 3          9       10            6             2        1  ...         6
# 4          8        5            4             7        6  ...         6
#
#    q18_acoustic  q18_coloutful  q18_full  q18_full  q19_warm  q19_acoustic
# 0             8              9         9         9         8             8  \
# 1             7              6         7         4         7             4
# 2             9              9         9         9         8             5
# 3            10              8         4         4         1             5
# 4             6              5         5         5         6             5
#
#    q19_coloutful  q19_full  q19_full
# 0              8         8         8
# 1              7         7         4
# 2              8         6         8
# 3             10        10        10
# 4              5         5         6
#
# [5 rows x 101 columns]

# %%
experience = df['experience']
def return_exp(experience):
    list_1 = []
    for i in range(len(experience)):
        if(experience[i] == "No Experience"):
            list_1 += [0]
        else:
            list_1 += [1]
    return list_1

df['experience'] = return_exp(experience)
df
# Out:
#     experience  q0_warm  q0_acoustic  q0_colourful  q0_full  q0_energy
# 0            1        7            8             7        7          7  \
# 1            0        3            4             7        4          3
# 2            1        7            9             9        9         10
# 3            1       10            9            10       10          9
# 4            1        6            7             8        6          8
# 5            0        8            8             6        8          7
# 6            1        2            4             6        3          4
# 7            0        2            5             9        4          8
# 8            0        4            5             7        4          6
# 9            0        7            9             8        8          8
# 10           0        6            8             8        1          5
# 11           0        4            6             9        5          9
# 12           0        5            4             6        6          4
# 13           0        2            3             5        3          6
# 14           0        5            7             8        8          8
# 15           0        5            8             8        8          9
# 16           0        7            8             6        6          7
# 17           0        6            8             6        5          7
# 18           1        6            3             7        3          5
# 19           1        3            7             4        7          8
# 20           0        8            7             8        8          9
# 21           0        7            6             8        6          8
# 22           1        3            3             6        6          8
# 23           0        5            5             8        6          8
# 24           0        1            3             4        3          5
# 25           0        8            9             5        6          7
# 26           0        4            4             4        4          5
# 27           0        7            6             8        7          9
# 28           0        8            7             9        5          8
# 29           0        5            4             4        5          8
# 30           1        4            8             3        5          4
# 31           1        8            7             8        2          8
# 32           1        6            6             5        5          5
# 33           1        6           10             4        5          7
# 34           1        7            8             6        9          6
# 35           0        4            8             8        6          8
# 36           1        2            7             4        4          7
# 37           1        8            8             7        8          9
# 38           1        2            2             3        3          5
# 39           1        8            8             4        3          3
# 40           0        7            8             6        8         10
# 41           1        7            8             3        7          4
# 42           1        7            6             9        6          8
# 43           1        6            6             4        3          3
# 44           1        4            7             2        2          5
# 45           0        6            7             3        2          2
#
#     q1_warm  q1_acoustic  q1_coloutful  q1_full  ...  q18_warm  q18_acoustic
# 0         7            7             8        8  ...         9             8  \
# 1         4            3             7        5  ...         8             7
# 2         5            5             5        5  ...         8             9
# 3        10            6             2        1  ...         6            10
# 4         5            4             7        6  ...         6             6
# 5         8            7             7        7  ...         7             8
# 6         6            6             6        6  ...         4             4
# 7         2            6             8        5  ...         1             5
# 8         2            2             3        3  ...         7             7
# 9        10            8             8        9  ...         7             2
# 10       10            2             2        2  ...        10            10
# 11        5            7             6        6  ...         9             6
# 12        7            8             7        7  ...         8             7
# 13        5            2             5        4  ...         4             5
# 14        4            7             7        6  ...         4             4
# 15        7            8             8        8  ...         8             4
# 16        7            6             7        7  ...         7             8
# 17        7            7             7        8  ...         6             5
# 18        3            6             4        5  ...         6             4
# 19        6            4             8        8  ...         6             6
# 20        7            7             6        6  ...         8             8
# 21        5            7             6        7  ...         5             7
# 22        3            4             7        6  ...         6             6
# 23        4            5             7        5  ...         7             7
# 24        7            3             2        7  ...         5            10
# 25        6           10             7        6  ...         1             9
# 26        5            5             5        6  ...         7             6
# 27        9            9             8       10  ...        10            10
# 28        6            9             9        7  ...         7             8
# 29        2            7             6        9  ...         3             8
# 30        6            4             6        5  ...         7             8
# 31        9            6             6        2  ...         6             6
# 32        5            6             7        5  ...         6             6
# 33        8            4             8        8  ...         8            10
# 34        6            3             8        7  ...         7             5
# 35        7            3             7        6  ...         4             7
# 36        4            2             7        5  ...         4             6
# 37        9            8             9        9  ...         6             4
# 38        4            4             6        5  ...         3             3
# 39        7            5             9        7  ...         8             7
# 40       10            3             9        9  ...         9             9
# 41        8            4             6        4  ...         6             5
# 42        5            4            10        8  ...         8             7
# 43        7            6             7        4  ...         1             2
# 44        5            8             8        6  ...         8             6
# 45        6            6             7        3  ...         5             5
#
#     q18_coloutful  q18_full  q18_full  q19_warm  q19_acoustic  q19_coloutful
# 0               9         9         9         8             8              8  \
# 1               6         7         4         7             4              7
# 2               9         9         9         8             5              8
# 3               8         4         4         1             5             10
# 4               5         5         5         6             5              5
# 5               8         7         8         8             8              8
# 6               4         4         5         3             4              4
# 7               6         7         8         3             2              5
# 8               5         7         9         8             8              8
# 9               4         4         7         5             5              4
# 10             10        10        10         6             5              7
# 11              8         7         6         8             6              6
# 12              8         7         7         7             7              8
# 13              6         7         5         6             5              7
# 14              4         4         3         6             4              4
# 15              6         5         5         7             6              5
# 16              7         7         8         6             6              7
# 17              7         6         6         6             5              6
# 18              6         3         6         6             3              5
# 19             10        10         2         3             3              5
# 20              8         8         9         8             8              9
# 21              9         5         6         6             5              8
# 22              8         8         9        10             9              9
# 23              8         7         7         5             5              5
# 24              3         6         6         7             3              4
# 25              8         8         4         1             5              7
# 26              5         7         5        10             6              2
# 27              9         9        10         9             9              9
# 28              6         7         9         7             7              7
# 29              7         8         9         2             7              8
# 30              8         8         8         6             7              6
# 31              6         4         7         5             5              4
# 32              5         7         6         7             6              5
# 33             10         7         7         5             4              7
# 34              8         8         9         6             2              9
# 35              7         4         7         6             4              3
# 36              6         4         7         6             4              4
# 37              6         5         7         7             4              6
# 38              4         5         3         5             5              7
# 39              8         8         7         8             8              6
# 40             10        10         8         8             9              8
# 41              7         8         7         6             7              8
# 42              4         4         7         7             3              5
# 43              7         5         2         7             7             10
# 44              6         7         9         9             7              8
# 45              7         4         5         4             5              4
#
#     q19_full  q19_full
# 0          8         8
# 1          7         4
# 2          6         8
# 3         10        10
# 4          5         6
# 5          8         8
# 6          4         5
# 7          7         7
# 8          9         8
# 9          3         6
# 10         5         8
# 11         4         9
# 12         6         7
# 13         7         7
# 14         3         3
# 15         6         7
# 16         7         7
# 17         6         6
# 18         2         6
# 19         6         6
# 20         9         9
# 21         7         7
# 22         9         9
# 23         6         6
# 24         7         6
# 25         7         4
# 26         6         2
# 27         9        10
# 28         8         8
# 29         9        10
# 30         8         6
# 31         5         5
# 32         6         6
# 33         2         4
# 34         7         5
# 35         6         8
# 36         4         5
# 37         7         8
# 38         6         6
# 39         8         9
# 40         9         7
# 41         8         9
# 42         4         7
# 43         6         8
# 44         4         9
# 45         5         6
#
# [46 rows x 101 columns]

# %%
df_experience = df[df['experience'] == 1].drop(['experience'], axis = 1)
df_unexperience = df[df['experience'] == 0].drop(['experience'], axis = 1)

# %%
df_experience
# Out:
#     q0_warm  q0_acoustic  q0_colourful  q0_full  q0_energy  q1_warm
# 0         7            8             7        7          7        7  \
# 2         7            9             9        9         10        5
# 3        10            9            10       10          9       10
# 4         6            7             8        6          8        5
# 6         2            4             6        3          4        6
# 18        6            3             7        3          5        3
# 19        3            7             4        7          8        6
# 22        3            3             6        6          8        3
# 30        4            8             3        5          4        6
# 31        8            7             8        2          8        9
# 32        6            6             5        5          5        5
# 33        6           10             4        5          7        8
# 34        7            8             6        9          6        6
# 36        2            7             4        4          7        4
# 37        8            8             7        8          9        9
# 38        2            2             3        3          5        4
# 39        8            8             4        3          3        7
# 41        7            8             3        7          4        8
# 42        7            6             9        6          8        5
# 43        6            6             4        3          3        7
# 44        4            7             2        2          5        5
#
#     q1_acoustic  q1_coloutful  q1_full  q1_full  ...  q18_warm  q18_acoustic
# 0             7             8        8        8  ...         9             8  \
# 2             5             5        5        6  ...         8             9
# 3             6             2        1        3  ...         6            10
# 4             4             7        6        7  ...         6             6
# 6             6             6        6        5  ...         4             4
# 18            6             4        5        4  ...         6             4
# 19            4             8        8        8  ...         6             6
# 22            4             7        6        6  ...         6             6
# 30            4             6        5        3  ...         7             8
# 31            6             6        2        7  ...         6             6
# 32            6             7        5        6  ...         6             6
# 33            4             8        8        7  ...         8            10
# 34            3             8        7        8  ...         7             5
# 36            2             7        5        8  ...         4             6
# 37            8             9        9        9  ...         6             4
# 38            4             6        5        6  ...         3             3
# 39            5             9        7        7  ...         8             7
# 41            4             6        4        7  ...         6             5
# 42            4            10        8        6  ...         8             7
# 43            6             7        4        5  ...         1             2
# 44            8             8        6        9  ...         8             6
#
#     q18_coloutful  q18_full  q18_full  q19_warm  q19_acoustic  q19_coloutful
# 0               9         9         9         8             8              8  \
# 2               9         9         9         8             5              8
# 3               8         4         4         1             5             10
# 4               5         5         5         6             5              5
# 6               4         4         5         3             4              4
# 18              6         3         6         6             3              5
# 19             10        10         2         3             3              5
# 22              8         8         9        10             9              9
# 30              8         8         8         6             7              6
# 31              6         4         7         5             5              4
# 32              5         7         6         7             6              5
# 33             10         7         7         5             4              7
# 34              8         8         9         6             2              9
# 36              6         4         7         6             4              4
# 37              6         5         7         7             4              6
# 38              4         5         3         5             5              7
# 39              8         8         7         8             8              6
# 41              7         8         7         6             7              8
# 42              4         4         7         7             3              5
# 43              7         5         2         7             7             10
# 44              6         7         9         9             7              8
#
#     q19_full  q19_full
# 0          8         8
# 2          6         8
# 3         10        10
# 4          5         6
# 6          4         5
# 18         2         6
# 19         6         6
# 22         9         9
# 30         8         6
# 31         5         5
# 32         6         6
# 33         2         4
# 34         7         5
# 36         4         5
# 37         7         8
# 38         6         6
# 39         8         9
# 41         8         9
# 42         4         7
# 43         6         8
# 44         4         9
#
# [21 rows x 100 columns]

# %%
df_unexperience
# Out:
#     q0_warm  q0_acoustic  q0_colourful  q0_full  q0_energy  q1_warm
# 1         3            4             7        4          3        4  \
# 5         8            8             6        8          7        8
# 7         2            5             9        4          8        2
# 8         4            5             7        4          6        2
# 9         7            9             8        8          8       10
# 10        6            8             8        1          5       10
# 11        4            6             9        5          9        5
# 12        5            4             6        6          4        7
# 13        2            3             5        3          6        5
# 14        5            7             8        8          8        4
# 15        5            8             8        8          9        7
# 16        7            8             6        6          7        7
# 17        6            8             6        5          7        7
# 20        8            7             8        8          9        7
# 21        7            6             8        6          8        5
# 23        5            5             8        6          8        4
# 24        1            3             4        3          5        7
# 25        8            9             5        6          7        6
# 26        4            4             4        4          5        5
# 27        7            6             8        7          9        9
# 28        8            7             9        5          8        6
# 29        5            4             4        5          8        2
# 35        4            8             8        6          8        7
# 40        7            8             6        8         10       10
# 45        6            7             3        2          2        6
#
#     q1_acoustic  q1_coloutful  q1_full  q1_full  ...  q18_warm  q18_acoustic
# 1             3             7        5        6  ...         8             7  \
# 5             7             7        7        8  ...         7             8
# 7             6             8        5        7  ...         1             5
# 8             2             3        3        8  ...         7             7
# 9             8             8        9        6  ...         7             2
# 10            2             2        2        2  ...        10            10
# 11            7             6        6        7  ...         9             6
# 12            8             7        7        7  ...         8             7
# 13            2             5        4        6  ...         4             5
# 14            7             7        6        8  ...         4             4
# 15            8             8        8        9  ...         8             4
# 16            6             7        7        8  ...         7             8
# 17            7             7        8        8  ...         6             5
# 20            7             6        6        7  ...         8             8
# 21            7             6        7        7  ...         5             7
# 23            5             7        5        6  ...         7             7
# 24            3             2        7        8  ...         5            10
# 25           10             7        6        9  ...         1             9
# 26            5             5        6        5  ...         7             6
# 27            9             8       10        9  ...        10            10
# 28            9             9        7        9  ...         7             8
# 29            7             6        9        9  ...         3             8
# 35            3             7        6        8  ...         4             7
# 40            3             9        9       10  ...         9             9
# 45            6             7        3        3  ...         5             5
#
#     q18_coloutful  q18_full  q18_full  q19_warm  q19_acoustic  q19_coloutful
# 1               6         7         4         7             4              7  \
# 5               8         7         8         8             8              8
# 7               6         7         8         3             2              5
# 8               5         7         9         8             8              8
# 9               4         4         7         5             5              4
# 10             10        10        10         6             5              7
# 11              8         7         6         8             6              6
# 12              8         7         7         7             7              8
# 13              6         7         5         6             5              7
# 14              4         4         3         6             4              4
# 15              6         5         5         7             6              5
# 16              7         7         8         6             6              7
# 17              7         6         6         6             5              6
# 20              8         8         9         8             8              9
# 21              9         5         6         6             5              8
# 23              8         7         7         5             5              5
# 24              3         6         6         7             3              4
# 25              8         8         4         1             5              7
# 26              5         7         5        10             6              2
# 27              9         9        10         9             9              9
# 28              6         7         9         7             7              7
# 29              7         8         9         2             7              8
# 35              7         4         7         6             4              3
# 40             10        10         8         8             9              8
# 45              7         4         5         4             5              4
#
#     q19_full  q19_full
# 1          7         4
# 5          8         8
# 7          7         7
# 8          9         8
# 9          3         6
# 10         5         8
# 11         4         9
# 12         6         7
# 13         7         7
# 14         3         3
# 15         6         7
# 16         7         7
# 17         6         6
# 20         9         9
# 21         7         7
# 23         6         6
# 24         7         6
# 25         7         4
# 26         6         2
# 27         9        10
# 28         8         8
# 29         9        10
# 35         6         8
# 40         9         7
# 45         5         6
#
# [25 rows x 100 columns]

# %%
def split_df(df):
    dfs = np.array_split(df, len(df.columns)//5, axis = 1)
    return dfs

dfs_experience = split_df(df_experience)
dfs_unexperience = split_df(df_unexperience)

mean_experience = np.array([j.mean().values for j in dfs_experience])
mean_unexperience = np.array([j.mean().values for j in dfs_unexperience])

# %%
def convert_bool(mean_array):
    for i in range(len(mean_array)):
        for j in range(len(mean_array[i])):
            if(mean_array[i][j] > 5):
                mean_array[i][j] = 1
            else:
                mean_array[i][j] = 0
    return mean_array


bin_mean_exp = convert_bool(mean_experience)
bin_mean_unexp = convert_bool(mean_unexperience)
# Out:
# (20, 5)
